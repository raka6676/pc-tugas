# %% [markdown]
# # DOKUMENTASI KIVY
#
# __Oleh:__
#
#     1. Rizqi Afif Khairullah (180441100034)
#     2. Ahmad Marzuq Alhimni  (180441100071)
#
# **Pengertian Kivy**
#
#    Kivy adalah GUI/NUI framework yang menggunakan bahasa pemrograman Python, dapat dijalankan pada Windows, Linux, OS X, Android dan iOS dengan menggunakan code yang sama dan menggunakan MIT license sehingga 100% free to use dan boleh dikomersialisasikan. Kivy didesain untuk membantu pembuatan dan pengembangan aplikasi cross-platform secara cepat.
#
# **CARA INSTALASI KIVY**
#
# Pastikan terhubung ke internet
#
#    >Pada tampilan cmd silahkan anda ketik perintah dibawah ini lalu tekan enter
#
# python -m pip install --upgrade pip wheel setuptools
#
#    >Jika langkah pertama sudah selesai ketik perintah berikut pada cmd pula, tunggu hingga proses selesai
#
# python -m pip install docutils pygments pypiwin32 kivy.deps.sdl2 kivy.deps.glew
#
#    >Sama seperti sebelumya
#
# python -m pip install kivy.deps.gstreamer
#
#    >Langkah terakhir
#
# python -m pip install kivy
#
# # Penjelasan Class
#
# **1. Class Calculator**
#
# Dalam Class Calculator terdapat 3 method yaitu:
#    1. execute
#        Yaitu untuk menginisialisasi semua button yang ada disitu
#    2. exeOp
#        Yaitu untuk mengaktifkan button fungsi matematika
#    3. setText
#        Untuk menambahkan inputan baru pada inputan yang sudah ada
#
# **2. Class CalcApp**
#
# Pada Class ini hanya terdapat satu class yaitu:
#     Build
#         Yaitu untuk mensetting Aplikasi Kalkulator
#
# # KONSEP OOP
# Pada aplikasi ini menggunakan konsep OOP inheritance
#
# Seperti Class Calculator menginheritance dari Widget di kivy
#
# ![class%201.JPG](attachment:class%201.JPG)
#
# dan Class CalcApp menginheritance dari App di kivy
#
# ![class%202.JPG](attachment:class%202.JPG)
#
# # PENJELASAN VARIABEL
#
# ![kivy.jpg](attachment:kivy.jpg)
#
# # SCREENSHOOT APLIKASI
#
# ![kivy%20apk.jpg](attachment:kivy%20apk.jpg)
